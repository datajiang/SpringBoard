# %% [markdown]
# ****
# ## World Bank Projects Survey

# %%
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

df = pd.read_json('data/world_bank_projects.json')

# %%
str_data = json.load((open('data/world_bank_projects.json')))
theme = json_normalize(str_data, 'mjtheme_namecode')

# %%
# dictionary for filling empty entries
theme_dict = dict(zip(theme.code, theme.name))

print(theme_dict)
  # theme_dict['1'] = 'Economic management'
  # theme_dict['6'] = 'Social protection and risk management'
  # print(theme_dict)
  # theme_dict['1']
# Out:
# {'8': 'Human development', '11': 'Environment and natural resources management', '1': '', '6': '', '5': 'Trade and integration', '2': 'Public sector governance', '7': 'Social dev/gender/inclusion', '4': 'Financial and private sector development', '10': 'Rural development', '9': 'Urban development', '3': 'Rule of law'}

# %%
print(list(zip(theme.code, theme.name)))
# Out:
# [('8', 'Human development'), ('11', ''), ('1', 'Economic management'), ('6', 'Social protection and risk management'), ('5', 'Trade and integration'), ('2', 'Public sector governance'), ('11', 'Environment and natural resources management'), ('6', 'Social protection and risk management'), ('7', 'Social dev/gender/inclusion'), ('7', 'Social dev/gender/inclusion'), ('5', 'Trade and integration'), ('4', 'Financial and private sector development'), ('6', 'Social protection and risk management'), ('6', ''), ('2', 'Public sector governance'), ('4', 'Financial and private sector development'), ('11', 'Environment and natural resources management'), ('8', ''), ('10', 'Rural development'), ('7', ''), ('2', 'Public sector governance'), ('2', 'Public sector governance'), ('2', 'Public sector governance'), ('10', 'Rural development'), ('2', ''), ('10', 'Rural development'), ('6', 'Social protection and risk management'), ('6', 'Social protection and risk management'), ('11', 'Environment and natural resources management'), ('4', ''), ('5', 'Trade and integration'), ('11', 'Environment and natural resources management'), ('10', 'Rural development'), ('6', 'Social protection and risk management'), ('6', 'Social protection and risk management'), ('6', 'Social protection and risk management'), ('10', 'Rural development'), ('11', 'Environment and natural resources management'), ('5', 'Trade and integration'), ('10', 'Rural development'), ('2', ''), ('8', 'Human development'), ('7', ''), ('8', 'Human development'), ('8', 'Human development'), ('2', 'Public sector governance'), ('7', 'Social dev/gender/inclusion'), ('8', 'Human development'), ('2', 'Public sector governance'), ('2', 'Public sector governance'), ('2', 'Public sector governance'), ('7', 'Social dev/gender/inclusion'), ('7', 'Social dev/gender/inclusion'), ('9', 'Urban development'), ('7', 'Social dev/gender/inclusion'), ('7', 'Social dev/gender/inclusion'), ('7', 'Social dev/gender/inclusion'), ('8', 'Human development'), ('8', 'Human development'), ('10', 'Rural development'), ('10', 'Rural development'), ('10', 'Rural development'), ('6', 'Social protection and risk management'), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('4', 'Financial and private sector development'), ('5', 'Trade and integration'), ('2', 'Public sector governance'), ('8', 'Human development'), ('11', 'Environment and natural resources management'), ('2', 'Public sector governance'), ('5', 'Trade and integration'), ('6', 'Social protection and risk management'), ('10', 'Rural development'), ('10', 'Rural development'), ('7', 'Social dev/gender/inclusion'), ('7', 'Social dev/gender/inclusion'), ('11', 'Environment and natural resources management'), ('8', 'Human development'), ('4', ''), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('4', 'Financial and private sector development'), ('6', 'Social protection and risk management'), ('1', 'Economic management'), ('4', 'Financial and private sector development'), ('2', 'Public sector governance'), ('8', 'Human development'), ('5', 'Trade and integration'), ('5', 'Trade and integration'), ('7', 'Social dev/gender/inclusion'), ('10', 'Rural development'), ('4', 'Financial and private sector development'), ('10', 'Rural development'), ('11', ''), ('6', 'Social protection and risk management'), ('7', ''), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('6', 'Social protection and risk management'), ('11', 'Environment and natural resources management'), ('11', 'Environment and natural resources management'), ('2', 'Public sector governance'), ('4', '' ...
