# %%
import pandas as pd
import numpy as np
import re
import time

start = time.time()

df = pd.read_csv('cars.csv', low_memory=False)
pd.set_option('display.max_columns', 234)

# %%
df = df.transpose()

# %%
df.shape
# Out:
# (32316, 234)

# %%
# df.get_dtype_counts

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32316 entries, 0 to 32315
# Columns: 235 entries, index to Hybrid/Electric Components Note
# dtypes: object(235)
# memory usage: 57.9+ MB

# %%
# df.describe()

# %% [markdown]
# ## Removing Extraneous Data
#
#
# **Columns with 100% missing values**
#
# These columns contain no information and are removed from the dataset in the code below.

# %%
# Removing columns with 100% missing values
df = df.dropna(how='all', axis=1)
print('The size of the dataset: ' + str(df.shape))
# Out:
# The size of the dataset: (32316, 231)

# %% [markdown]
# ### Remove duplicates

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32316 entries, 0 to 32315
# Columns: 231 entries, index to Hybrid/Electric Components Note
# dtypes: object(231)
# memory usage: 57.2+ MB

# %% [markdown]
# ### Remove columns with only one unique value

# %%
# removing columns with only one unique value , args=(False)

df = df.loc[:,df.apply(func=pd.Series.nunique) > 1]

print('The size of the removed dataset: ', df.shape)
# Out:
# The size of the removed dataset:  (32316, 228)

# %% [markdown]
# # Prepare target column
# It has missing values. Drop the those rows from dataset. Remove $ sign and ','.

# %%
df = df[df['MSRP'].notnull()]
print(df.shape)
# Out:
# (32262, 228)

# %%
df.loc[:, 'MSRP'] = df.loc[:, 'MSRP'].apply(lambda x: x.replace('$', '').replace(',', ''))
df['MSRP'] = pd.to_numeric(df['MSRP'], errors='coerse')
df['MSRP'].head()
# Out:
# 0    40600
# 1    45500
# 2    43600
# 3    37400
# 4    42600
# Name: MSRP, dtype: int64

# %% [markdown]
# ### Extract Year and Model from one column

# %%
df['Year'] = df['index'].str[:4]

# %%
df['Year'].dtype
# Out:
# dtype('O')

# %%
df['Year'] = df['Year'].astype('category')
df['Year'].dtype
# Out:
# category

# %%
df['Specs'] = df['index'].str[5:]

# %%
# df['Specs'] = df['Specs'].str.split(pat=' Specs: ')

# %% [markdown]
# # ??? Is there a better way to write this code???

# %%
for idx, item in df['index'].iteritems():
    df.loc[idx, 'Model'] = item.split(' Specs: ')[0]
    df.loc[idx, 'Specs'] = item.split(' Specs: ')[1]

# %% [markdown]
# ### Size and Volume data cleaning

# %%
df['Volume'] = df['Cargo Volume (ft³)']
df['Width'] = df['Width, Max w/o mirrors (in)']
df['Height'] = df['Height, Overall (in)']
df['Length'] = df['Length, Overall (in)']

size_list = ['Volume', 'Width', 'Height', 'Length']

# %%
# Check non-null
df[size_list].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32262 entries, 0 to 32315
# Data columns (total 4 columns):
# Volume    7522 non-null object
# Width     30212 non-null object
# Height    30230 non-null object
# Length    17486 non-null object
# dtypes: object(4)
# memory usage: 2.5+ MB

# %%
def to_float(col_list):
    for col in col_list:
    # df[col] = df[col].fillna('')
        df.loc[:, col] = pd.to_numeric(df.loc[:, col], errors='coerce')

# %%
to_float(size_list)

# %%
# Additional column for average of 3 dimensions
df['Size_avg'] = df[['Width', 'Length', 'Height']].sum(axis=1) / 3

# final for features
size_list = ['Volume', 'Width','Height','Length', 'Size_avg']

# %%
df[size_list].head()
# Out:
#    Volume  Width  Height  Length   Size_avg
# 0     NaN   74.8    65.7     NaN  46.833333
# 1     NaN   74.8    65.7     NaN  46.833333
# 2     NaN   74.8    65.7     NaN  46.833333
# 3     NaN   74.8    65.7     NaN  46.833333
# 4     NaN   74.8    65.7     NaN  46.833333

# %% [markdown]
# ### Weight data cleaning

# %%
weight_list_short = [
 'Gross Combined Wt Rating (lbs)',    
 'Maximum Trailering Capacity (lbs)',
 'Gross Vehicle Weight Rating Cap (lbs)'
]

# %%
df['Weight'] = df['Gross Combined Wt Rating (lbs)']
df['Trailer_cpt'] = df['Maximum Trailering Capacity (lbs)']

# %%
# df = df.drop(['Gross Combined Wt Rating (lbs)', 'Maximum Trailering Capacity (lbs)'], axis=1)

# %%
weight_list_short = ['Weight', 'Trailer_cpt']

# %%
to_float(weight_list_short)

# %%
# update list for features
weight_list = ['Weight', 'Trailer_cpt']

# examine data
df[weight_list].head()
# Out:
#    Weight  Trailer_cpt
# 0     NaN          NaN
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN

# %% [markdown]
# ### Fuel data cleaning

# %%
fuel_economy_list_short = [
 'Fuel Tank Capacity, Approx (gal)',
 'Fuel Economy Est-Combined (MPG)',
 'EPA Fuel Economy Est - City (MPG)',
 'EPA Fuel Economy Est - Hwy (MPG)'
]

# %%
df['Fuel_Tank_Cpt'] = df['Fuel Tank Capacity, Approx (gal)']
df['MPG_avg'] = df['Fuel Economy Est-Combined (MPG)']
df['MPG_City'] = df['EPA Fuel Economy Est - City (MPG)']
df['MPG_Hwy'] = df['EPA Fuel Economy Est - Hwy (MPG)']

fuel_economy_list_short =['Fuel_Tank_Cpt', 'MPG_avg', 'MPG_City', 'MPG_Hwy']

# %%
# extract numeric data
def clean(col):
    df[col] = df[col].fillna('')
    df[col] = df[col].apply(lambda x: x[:2] if r'(' in x else x)

clean('MPG_avg')
clean('MPG_City')
clean('MPG_Hwy')

to_float(fuel_economy_list_short)

# %%
# update list to be used as features
fuel_economy_list =['Fuel_Tank_Cpt', 'MPG_avg', 'MPG_City', 'MPG_Hwy']

# examine cleaned data
df[fuel_economy_list].head()
# Out:
#    Fuel_Tank_Cpt  MPG_avg  MPG_City  MPG_Hwy
# 0           17.1     24.0      22.0     28.0
# 1           17.1     24.0      22.0     28.0
# 2           17.1     24.0      22.0     27.0
# 3           17.1     24.0      22.0     28.0
# 4           17.1     23.0      21.0     27.0

# %% [markdown]
# # Transmission data cleaning

# %%
trans_list = [
 'Trans Description Cont.',
 'Trans Order Code',
 'Trans Description Cont. Again',
 'Trans Type',
 'Trans PTO Access',
 'Transmission',
 'Trans Power Take Off']

# %%
df['Trans_Speed'] = df['Trans Type']

# %%
# to numeric values
trans_list_to_float = ['Trans_Speed']
to_float(trans_list_to_float)

# %%
# update list to be used as features
trans_list = ['Trans_Speed']

# examine cleaned data
df[trans_list].head()
# Out:
#    Trans_Speed
# 0         10.0
# 1         10.0
# 2         10.0
# 3         10.0
# 4         10.0

# %% [markdown]
# ## Safety data cleaning

# %%
safety_list = [
 'Air Bag-Frontal-Driver',
 'Air Bag-Frontal-Passenger',
 'Air Bag-Passenger Switch (On/Off)',
 'Air Bag-Side Body-Front',
 'Air Bag-Side Body-Rear',
 'Air Bag-Side Head-Front',
 'Air Bag-Side Head-Rear',
 'Child Safety Rear Door Locks',
 'Daytime Running Lights',
 'Traction Control',
 'Night Vision',
 'Rollover Protection Bars',
 'Fog Lamps',
 'Parking Aid',
 'Tire Pressure Monitor',
 'Back-Up Camera',
 'Stability Control'
]

# %%
# safety_list dictionary for renaming purpose
dict1 = {'Air Bag-Frontal-Driver': 'Airbag_Front_Driver',
 'Air Bag-Frontal-Passenger': 'Airbag_Front_Psg',
 'Air Bag-Passenger Switch (On/Off)':'Airbag_Psg_Switch',
 'Air Bag-Side Body-Front': 'Airbag_SBF',
 'Air Bag-Side Body-Rear': 'Airbag_SBR',
 'Air Bag-Side Head-Front': 'Airbag_SHF',
 'Air Bag-Side Head-Rear': 'Airbag_SHR',
 'Child Safety Rear Door Locks': 'Child_Door_Locks',
 'Daytime Running Lights': 'Day_Lights',
 'Traction Control': 'Trac_Control',
 'Night Vision': 'Night_Vision',
 'Rollover Protection Bars': 'Rollover_Prt',
 'Fog Lamps': 'Fog_Lamps','Parking Aid': 'Parking_Aid',
 'Tire Pressure Monitor': 'Tire_P_Monitor',
 'Back-Up Camera': 'Backup_Camera',
 'Stability Control': 'Stability_Ctl'}

# %%
# function to update a list after renaming some columns
def update_list_by_dict(col_list, dict):
    for x in col_list:
        if x in list(dict.keys()):
            index = col_list.index(x)
            col_list[index] = dict[x]

update_list_by_dict(safety_list, dict1)

# %%
# rename column name
df.rename(columns=dict1, inplace=True)

# examine cleaned data
df[safety_list].head()
# Out:
#   Airbag_Front_Driver Airbag_Front_Psg Airbag_Psg_Switch Airbag_SBF  \
# 0                 Yes              Yes                No        Yes
# 1                 Yes              Yes                No        Yes
# 2                 Yes              Yes                No        Yes
# 3                 Yes              Yes                No        Yes
# 4                 Yes              Yes                No        Yes
#
#   Airbag_SBR Airbag_SHF Airbag_SHR Child_Door_Locks Day_Lights Trac_Control  \
# 0         No        Yes        Yes              Yes        Yes          Yes
# 1         No        Yes        Yes              Yes        Yes          Yes
# 2         No        Yes        Yes              Yes        Yes          Yes
# 3         No        Yes        Yes              Yes        Yes          Yes
# 4         No        Yes        Yes              Yes        Yes          Yes
#
#   Night_Vision Rollover_Prt Fog_Lamps Parking_Aid Tire_P_Monitor  \
# 0           No           No        No         Yes            Yes
# 1           No           No       Yes         Yes            Yes
# 2           No           No       Yes         Yes            Yes
# 3           No           No        No          No            Yes
# 4           No           No        No         Yes            Yes
#
#   Backup_Camera Stability_Ctl
# 0           Yes           Yes
# 1           Yes           Yes
# 2           Yes           Yes
# 3           Yes           Yes
# 4           Yes           Yes

# %% [markdown]
# ## Brake data cleaning - remove

# %%
brake_list = [
 'Drum - Rear (Yes or   )',                         
 'Disc - Front (Yes or   )',                           
 'Brake Type',
 'Brake ABS System'
]

# %%
df[brake_list][:3]
# Out:
#   Drum - Rear (Yes or   ) Disc - Front (Yes or   )    Brake Type  \
# 0                     NaN                      Yes  4-Wheel Disc
# 1                     NaN                      Yes  4-Wheel Disc
# 2                     NaN                      Yes  4-Wheel Disc
#
#   Brake ABS System
# 0          4-Wheel
# 1          4-Wheel
# 2          4-Wheel

# %%
# not to used for now
brake_list =[]

# %% [markdown]
# ## Gear ratio data cleaning. It doesn't seem to be important!

# %%
gear_ratio_list = [
 'First Gear Ratio (:1)',
 'Second Gear Ratio (:1)',
 'Third Gear Ratio (:1)',
 'Fourth Gear Ratio (:1)',
 'Fifth Gear Ratio (:1)',
 'Sixth Gear Ratio (:1)',
 'Seventh Gear Ratio (:1)',
 'Eighth Gear Ratio (:1)',
 'Ninth Gear Ratio (:1)',
 'Tenth Gear Ratio (:1)',
 'Final Drive Axle Ratio (:1)',
 'Reverse Ratio (:1)',
]

# %%
# not to be used for now
gear_ratio_list = []

# %% [markdown]
# ## Suspension data cleaning

# %%
suspension_list = [
 'Suspension Type - Front',
 'Suspension Type - Front (Cont.)',
 'Suspension Type - Rear',
 'Suspension Type - Rear (Cont.)'
]

# %%
# suspension_list
dict = {'Suspension Type - Front': 'Susp_Front',
 'Suspension Type - Front (Cont.)': 'Susp_Front2',
 'Suspension Type - Rear': 'Susp_Rear',
 'Suspension Type - Rear (Cont.)': 'Susp_Rear2'}

# rename column name
df.rename(columns=dict, inplace=True)

# update column list
update_list_by_dict(suspension_list, dict)

# %% [markdown]
# ## Axle data cleaning - removed

# %%
axle_list = [
 'Axle Type - Rear',
 'Axle Type - Front',
 'Axle Ratio (:1) - Rear',
 'Axle Ratio (:1) - Front'
]

# %%
# not being used
axle_list = []

# %% [markdown]
# ## Battery data cleaning

# %%
battery_list = [
 'Battery Range (mi)',
 'Cold Cranking Amps @ 0° F (Primary)',
 'Cold Cranking Amps @ 0° F (2nd)'
]

# %%
df['Battery_Amps'] = df['Cold Cranking Amps @ 0° F (Primary)']
df = df.drop(['Cold Cranking Amps @ 0° F (Primary)'], axis=1)

# %%
# to numeric value
battery_list_to_float = ['Battery_Amps']
to_float(battery_list_to_float)

# %%
# update for features
battery_list =['Battery_Amps']

# examin cleaned data
df[battery_list].head()
# Out:
#    Battery_Amps
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## Engine data cleaning

# %%
engine_list = [
 'Engine Type',                           
 'Engine Order Code',                           
 'SAE Net Torque @ RPM',
 'SAE Net Horsepower @ RPM',
 'Displacement',    
 'Engine',    
 'Engine Oil Cooler'
]

df['HP1'] = df['SAE Net Torque @ RPM']
df['HP2'] = df['SAE Net Horsepower @ RPM']
df['Engine_Type'] = df['Engine Type']

df = df.drop(['SAE Net Torque @ RPM', 'SAE Net Horsepower @ RPM', 'Engine Type'], axis=1)

engine_list = ['HP1', 'HP2', 'Engine_Type']

# %% [markdown]
# How to make the following code to work?

# %%
# def clean_engine(col):
#    df[col] = df[col].fillna('')
#    df[col] = df[col].apply(lambda x: x[:3] if r'\@' in x else x)
#    df[col] = pd.to_numeric(df[col], errors='coerse')
# clean_engine('HP1')

# %%
# extract from extraneous characters
df['HP1'] = df['HP1'].str.replace(r' @ \d*', '')
df['HP1'] = df['HP1'].str.replace(r' - \d*', '')
df['HP2'] = df['HP2'].str.replace(r' @ \d*', '')
df['HP2'] = df['HP2'].str.replace(r' - \d*', '')

# conver to numeric
df['HP1'] = pd.to_numeric(df['HP1'], errors='coerse')
df['HP2'] = pd.to_numeric(df['HP2'], errors='coerse')

# %%
# examine cleaned data
df[engine_list].head()
# Out:
#      HP1    HP2                 Engine_Type
# 0  280.0  272.0  Turbo Premium Unleaded I-4
# 1  280.0  272.0  Turbo Premium Unleaded I-4
# 2  280.0  272.0  Turbo Premium Unleaded I-4
# 3  280.0  272.0  Turbo Premium Unleaded I-4
# 4  280.0  272.0  Turbo Premium Unleaded I-4

# %% [markdown]
# ### Clean up column 'Displacement'
# #### Detect empty cells or NaN

# %%
print('Number of missing entries:', df['Displacement'].isnull().sum())
# Out:
# Number of missing entries: 2137

# %% [markdown]
# #### Fill missing data with empty string to avoid error during cleaning operations.

# %%
df['Displacement'] = df['Displacement'].fillna('')
print('Number of missing entries:', df['Displacement'].isnull().sum())
# Out:
# Number of missing entries: 0

# %% [markdown]
# #### Examine the data

# %%
df['Displacement'][:5]
# Out:
# 0    2.0 L/122
# 1    2.0 L/122
# 2    2.0 L/122
# 3    2.0 L/122
# 4    2.0 L/122
# Name: Displacement, dtype: object

# %% [markdown]
# #### replace 'L/...' and strip white spaces right and left

# %%
df['Displacement'] = df['Displacement'].apply(lambda x: x.split('L')[0] if 'L' in x else x)

# %%
# examine cleaned data
df['Displacement'][:4]
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# Name: Displacement, dtype: object

# %% [markdown]
# #### The above shows data are not aligned, indicating white space existing.
# #### Strip leading and trailing white space

# %%
df['Displacement'] = df['Displacement'].str.strip()

# %% [markdown]
# #### Export to csv file and scroll using Excel. Found many dirty data.

# %%
with open('Displacement.csv','w') as f:
    df['Displacement'].to_csv(f, header=True)

# %% [markdown]
# #### Use len() to list out other data to be cleaned.

# %%
len_mask = df['Displacement'].apply(lambda x: True if len(x) >3 else False)
disp = df['Displacement'][len_mask]
disp[:7]
# Out:
# 1443    2.5/151
# 1448    2.5/151
# 1546    4.0/243
# 1658       6.75
# 1659       6.75
# 1660       6.75
# 1661       6.75
# Name: Displacement, dtype: object

# %% [markdown]
# #### Romove '/xx'

# %%
df['Displacement'] = df['Displacement'].apply(lambda x: x.split('/')[0] if '/' in x else x)

len_mask = df['Displacement'].apply(lambda x: True if len(x) >3 else False)
df['Displacement'][len_mask]
# Out:
# 1658                           6.75
# 1659                           6.75
# 1660                           6.75
# 1661                           6.75
# 1679                           6.75
# 1680                           6.75
# 1681                           6.75
# 2339                        - TBD -
# 2389                      2.5 (152)
# 2391                      2.5 (152)
# 2392                      2.5 (152)
# 2396                      2.5 (152)
# 2399                      2.5 (152)
# 2401                      2.5 (152)
# 2402                      2.5 (152)
# 2405                      2.5 (152)
# 2641     39.5 Cu.in. Range Extender
# 2642     39.5 Cu.in. Range Extender
# 2645     39.5 Cu.in. Range Extender
# 2646     39.5 Cu.in. Range Extender
# 2649     39.5 Cu.in. Range Extender
# 2651     39.5 Cu.in. Range Extender
# 2653     39.5 Cu.in. Range Extender
# 12108                          6.2l
# 12109                          6.2l
# 12141                          6.2l
# 12160                          6.2l
# 25833                          6.75
# 25836                          6.75
# 25837                          6.75
# 25839                          6.75
# 25840                          6.75
# 25846                          6.75
# 25847                          6.75
# Name: Displacement, dtype: object

# %%
df['Displacement'][2320:2345]
# Out:
# 2326        2.0
# 2327        4.4
# 2328        3.0
# 2329        3.0
# 2330        4.4
# 2331        3.0
# 2332        4.4
# 2333        3.0
# 2334        4.4
# 2335        3.0
# 2336        3.0
# 2337        4.4
# 2338        3.0
# 2339    - TBD -
# 2340        3.0
# 2341        4.8
# 2342        3.0
# 2343        3.0
# 2344        3.0
# 2345        3.0
# 2346        3.0
# 2347        4.8
# 2348        3.0
# 2349        3.0
# 2350        3.0
# Name: Displacement, dtype: object

# %% [markdown]
# ### Remove ' (152)'

# %%
# df['Displacement'][2389:2406].apply(lambda x: x[:3])
# df['Displacement'][2389:2406].apply(str.replace(r' (152)', ''))
df['Displacement'] = df['Displacement'].apply(lambda x: x[:3] if '152' in x else x)

# %%
df['Displacement'][2389:2406]
# Out:
# 2395    3.0
# 2396    2.5
# 2397    4.4
# 2398    3.0
# 2399    2.5
# 2400    4.4
# 2401    2.5
# 2402    2.5
# 2403    4.4
# 2404    3.0
# 2405    2.5
# 2406    5.0
# 2407    4.4
# 2408    3.0
# 2409    4.4
# 2410    2.8
# 2411    4.4
# Name: Displacement, dtype: object

# %%
# idx = []
# def get_idx(x):
#     if len(x) > 10:
#         idx.append(x.index)
#     return idx
# idx = df['Displacement'].apply(get_idx)
# df.loc[idx, 'Displacement']


cub_inch_cells = df['Displacement'].apply(lambda x: True if len(x) >10 else False)
df['Displacement'][cub_inch_cells]
# Out:
# 2641    39.5 Cu.in. Range Extender
# 2642    39.5 Cu.in. Range Extender
# 2645    39.5 Cu.in. Range Extender
# 2646    39.5 Cu.in. Range Extender
# 2649    39.5 Cu.in. Range Extender
# 2651    39.5 Cu.in. Range Extender
# 2653    39.5 Cu.in. Range Extender
# Name: Displacement, dtype: object

# %% [markdown]
# ### transform '39.5 Cu.in. Range Extender' to liter
# calculate from cubit inch to liter:

# %%
df['Displacement'] = df['Displacement'].apply(lambda x: x[:4] if 'Cu.in.' in x else x)
df['Displacement'] = df['Displacement'].apply(lambda x: str(x).replace('l', '') if 'l' in x else x)

# %%
df['Displacement'] = pd.to_numeric(df['Displacement'], errors='coerce')

# %%
df['Displacement'][cub_inch_cells].index

idx_for_converting_units = df['Displacement'][cub_inch_cells].index

df.loc[idx_for_converting_units, ['Displacement']]
# Out:
#       Displacement
# 2641          39.5
# 2642          39.5
# 2645          39.5
# 2646          39.5
# 2649          39.5
# 2651          39.5
# 2653          39.5

# %%
# transform units
df.loc[idx_for_converting_units, 'Displacement'] = df.loc[idx_for_converting_units, 'Displacement'].apply(lambda x: x*0.016)

# %%
import matplotlib.pyplot as plt
df['Displacement'].plot('hist', bins=20)
plt.show()

# %%
df.boxplot(column='Displacement')
plt.show()

# %%
# update for features
engine_list = ['HP1', 'HP2', 'Engine_Type', 'Displacement']

#exmaine cleaned data
df[engine_list].head()
# Out:
#      HP1    HP2                 Engine_Type  Displacement
# 0  280.0  272.0  Turbo Premium Unleaded I-4           2.0
# 1  280.0  272.0  Turbo Premium Unleaded I-4           2.0
# 2  280.0  272.0  Turbo Premium Unleaded I-4           2.0
# 3  280.0  272.0  Turbo Premium Unleaded I-4           2.0
# 4  280.0  272.0  Turbo Premium Unleaded I-4           2.0

# %% [markdown]
# ## Corrosion data cleaning

# %%
corrosion_list = [
 'Corrosion Miles/km',
 'Corrosion Years',
 'Corrosion Note']

df['Corrosion_Years'] = df['Corrosion Years']
df['Corrosion_Miles'] = df['Corrosion Miles/km']

df = df.drop(['Corrosion Years', 'Corrosion Miles/km'], axis=1)

# %%
# df['Corrosion Years'] = pd.to_numeric(df['Corrosion Years'], errors='coerse')

# %%
corrosion_list = ['Corrosion_Miles', 'Corrosion_Years']

# %%
df['Corrosion_Miles'] = df['Corrosion_Miles'].str.replace(',', '')

# %%
df['Corrosion_Miles'] = df['Corrosion_Miles'].str.replace('Unlimited', '300000')

# %%
df['Corrosion_Miles'] = pd.to_numeric(df['Corrosion_Miles'], errors='coerse')
df['Corrosion_Years'] = pd.to_numeric(df['Corrosion_Years'], errors='coerse')

# %%
# used as features
corrosion_list = ['Corrosion_Miles', 'Corrosion_Years']

# %% [markdown]
# ## Miscillaneous data cleaning

# %% [markdown]
#  drop non-essencial and repeated columns:
#
#  'Model', 'index',  'EPA Classification',  'Number of Passenger Doors',    'Rear Door Type', 'Front Tire Order Code',
#  'Rear Tire Order Code',
#  'Spare Tire Order Code',
#  'Spare Wheel Material',
#   'Roadside Assistance Note',
#   'Lock to Lock Turns (Steering)',
#  'Steering Ratio (:1), Overall',
#
#  'Hybrid/Electric Components Miles/km',
#  'Hybrid/Electric Components Years',
#  'Hybrid/Electric Components Note',
#
#  'Transfer Case Model',
#  'Transfer Case Gear Ratio (:1), High',
#  'Transfer Case Gear Ratio (:1), Low',
#  'Transfer Case Power Take Off',
#
#  'Warranty Note',
#  'Basic Note',
#  'Maintenance Note',
#
#   'Emissions Miles/km',
#  'Emissions Years',
#  'Emissions Note',
#   'EPA Air Pollution Score', 51 counts
#   ['Drivetrain Note'] 1135
#
#
#  'Steering Type',
#  'Steering Ratio (:1), On Center',
#  'Steering Ratio (:1), At Lock',
#
#
#  'Revolutions/Mile @ 45 mph - Spare',
#  'Revolutions/Mile @ 45 mph - Front',
#  'Revolutions/Mile @ 45 mph - Rear',

# %% [markdown]
# #### These two columns are the same. So remove one.

# %%
df[[ 'EPA Class', 'EPA Classification']].head()
# Out:
#                           EPA Class                EPA Classification
# 0  Small Sport Utility Vehicles 2WD  Small Sport Utility Vehicles 2WD
# 1  Small Sport Utility Vehicles 2WD  Small Sport Utility Vehicles 2WD
# 2  Small Sport Utility Vehicles 2WD  Small Sport Utility Vehicles 2WD
# 3  Small Sport Utility Vehicles 2WD  Small Sport Utility Vehicles 2WD
# 4  Small Sport Utility Vehicles 4WD  Small Sport Utility Vehicles 4WD

# %%
miscil = [
 'Year',
 'Model',
 'Specs',
 'MSRP',
 'EPA Class',
 'Body Style',
 'Drivetrain',
 'Passenger Capacity',
 'Passenger Doors',
 'Front Wheel Material',
 'Rear Wheel Material',
 'Basic Miles/km',
 'Basic Years',    
 'Drivetrain Miles/km',
 'Drivetrain Years',
 'Roadside Assistance Miles/km',
 'Roadside Assistance Years',
 'Maximum Alternator Capacity (amps)',
 'Maintenance Miles/km',
 'Maintenance Years',
 'Maximum Alternator Watts',
 'Other Features']

# %%
 miscil_to_float_cols = ['Passenger Capacity', 
 'Passenger Doors', 
 'Basic Miles/km', 
 'Basic Years', 
 'Drivetrain Miles/km', 
 'Drivetrain Years', 
 'Roadside Assistance Miles/km', 
 'Roadside Assistance Years', 
 'Maximum Alternator Capacity (amps)', 
 'Maintenance Miles/km', 
 'Maintenance Years',  
 'Maximum Alternator Watts']

# %%
# clean columns
df['Basic Miles/km'] = df['Basic Miles/km'].str.replace(',', '')
df['Roadside Assistance Miles/km'] = df['Roadside Assistance Miles/km'].str.replace(',', '')
df['Maintenance Miles/km'] = df['Maintenance Miles/km'].str.replace(',', '')
df['Drivetrain Miles/km'] = df['Drivetrain Miles/km'].str.replace(',', '')

# %%
# convert to numeric values
to_float(miscil_to_float_cols)

# %%
dict = {   
 'EPA Class': 'EPA_Class',
 'Body Style': 'Body_Stype',
 'Front Wheel Material': 'Front_Wheel_Mat',
 'Rear Wheel Material': 'Rear_Wheel_Mat',
'Passenger Capacity': 'Psg_Cp',
'Passenger Doors': 'Psg_Doors',
'Basic Miles/km': 'Basic_Miles',
'Basic Years': 'Basic_Year',
'Drivetrain Miles/km': 'Drivetrain_Miles',
'Drivetrain Years': 'Drivetrain_Years',
'Roadside Assistance Miles/km': 'Road_Assist_Miles',
'Roadside Assistance Years': 'Road_Assist_Years',
'Maximum Alternator Capacity (amps)':'Max_Alt_Cp',
'Maintenance Miles/km': 'Maint_Miles',
'Maintenance Years': 'Maint_Year',
'Maximum Alternator Watts': 'Max_Alt_Watts',
'Other Features': 'Other_Features'}

# %%
# update column lists            
update_list_by_dict(miscil, dict )
update_list_by_dict(miscil_to_float_cols, dict)

# %%
# rename columns
df.rename(columns=dict, inplace=True)

# %%
# Put together all features
features = [miscil, weight_list, size_list, gear_ratio_list, safety_list, fuel_economy_list, brake_list, 
                suspension_list, trans_list, axle_list, battery_list, engine_list, corrosion_list]
all = []
for i in range(len(features)):
    all += features[i]

# %%
df[all]
# Out:
#        Year                         Model  \
# 0      2019                2019 Acura RDX
# 32314         4.0           50000.0               4.0                NaN
# 32315         4.0           50000.0               4.0                NaN
#
#        Road_Assist_Years  Max_Alt_Cp  Maint_Miles  Maint_Year  Max_Alt_Watts  \
# 0                    4.0         NaN          NaN         NaN            NaN
# 1                    4.0         NaN          NaN         NaN            NaN
# 2                    4.0         NaN          NaN         NaN            NaN
# 3                    4.0         NaN          NaN         NaN            NaN
# 4                    4.0         NaN          NaN         NaN            NaN
# 5                    4.0         NaN          NaN         NaN            NaN
# 6                    4.0         NaN          NaN         NaN            NaN
# 7                    4.0       130.0          NaN         NaN            NaN
# 8                    4.0       130.0          NaN         NaN            NaN
# 9                    4.0       130.0          NaN         NaN            NaN
# 10                   4.0       130.0          NaN         NaN            NaN
# 11                   4.0       130.0          NaN         NaN            NaN
# 12                   4.0       130.0          NaN         NaN            NaN
# 13                   4.0       130.0          NaN         NaN            NaN
# 14                   4.0       130.0          NaN         NaN            NaN
# 15                   4.0       130.0          NaN         NaN            NaN
# 16                   4.0       130.0          NaN         NaN            NaN
# 17                   4.0       130.0          NaN         NaN            NaN
# 18                   4.0       130.0          NaN         NaN            NaN
# 19                   4.0       130.0          NaN         NaN            NaN
# 20                   4.0       130.0          NaN         NaN            NaN
# 21                   4.0       130.0          NaN         NaN            NaN
# 22                   4.0       130.0          NaN         NaN            NaN
# 23                   4.0       130.0          NaN         NaN            NaN
# 24                   4.0       130.0          NaN         NaN            NaN
# 25                   4.0       130.0          NaN         NaN            NaN
# 26                   4.0       130.0          NaN         NaN            NaN
# 27                   4.0       130.0          NaN         NaN            NaN
# 28                   4.0       130.0          NaN         NaN            NaN
# 29                   4.0       130.0          NaN         NaN            NaN
# ...                  ...         ...          ...         ...            ...
# 32286                4.0       140.0          NaN         NaN            NaN
# 32287                4.0       140.0          NaN         NaN            NaN
# 32288                4.0       140.0          NaN         NaN            NaN
# 32289                4.0       140.0          NaN         NaN            NaN
# 32290                4.0       140.0          NaN         NaN            NaN
# 32291                4.0       140.0          NaN         NaN            NaN
# 32292                4.0       140.0          NaN         NaN            NaN
# 32293                4.0       140.0          NaN         NaN            NaN
# 32294                4.0       140.0          NaN         NaN            NaN
# 32295                4.0       140.0          NaN         NaN            NaN
# 32296                4.0       140.0          NaN         NaN            NaN
# 32297                4.0       210.0      36000.0         3.0            NaN
# 32298                4.0       210.0      36000.0         3.0            NaN
# 32299                4.0       210.0      36000.0         3.0            NaN
# 32300                4.0       210.0      36000.0         3.0            NaN
# 32301                4.0       210.0      36000.0         3.0            NaN
# 32302                4.0       210.0      36000.0         3.0            NaN
# 32303                4.0       210.0      36000.0         3.0            NaN
# 32304                4.0       210.0      36000.0         3.0            NaN
# 32305                4.0       210.0      36000.0         3.0            NaN
# 32306                4.0       210.0      36000.0         3.0            NaN
# 32307                4.0       210.0      36000.0         3.0            NaN
# 32308                4.0       210.0      36000.0         3.0            NaN
# 32309                NaN       120.0          NaN         NaN            NaN
# 32310                4.0       210.0      36000.0         3.0            NaN
# 32311                4.0       210.0      36000.0         3.0            NaN
# 32312                4.0       150.0      36000.0         3.0            NaN
# 32313                4.0       150.0      36000.0         3.0            NaN
# 32314                4.0       150.0      36000.0         3.0            NaN
# 32315                4.0       150.0      36000.0         3.0            NaN
#
#                                           Other_Features  Weight  Trailer_cpt  \
# 0      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 1      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 2      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 3      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 4      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 5      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 6      Vehicle Stability Assist Electronic Stability ...     NaN          NaN
# 7      Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 8      Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 9      Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 10     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 11     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 12     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 13     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 14     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 15     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 16     Vehicle Stability Assist Electronic Stability ...     NaN       1500.0
# 17     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 18     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 19     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 20     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 21     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 22     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 23     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 24     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 25     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 26     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 27     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 28     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# 29     Electronic Stability Control (ESC)\r\nABS And ...     NaN       1500.0
# ...                                                  ...     ...          ...
# 32286  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32287  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32288  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32289  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32290  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32291  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32292  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32293  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32294  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32295  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32296  4-wheel Anti-lock Braking System (ABS)\r\nElec...     NaN          NaN
# 32297  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32298  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32299  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32300  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32301  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32302  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32303  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32304  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32305  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32306  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32307  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32308  Dstc/RSC Electronic Stability Control (ESC) An...     NaN          NaN
# 32309  4-wheel anti-lock brake system (ABS)\r\nDriver...     NaN          NaN
# 32310  DSTC Electronic Stability Control (ESC)\r\nABS...     NaN          NaN
# 32311  DSTC Electronic Stability Control (ESC)\r\nABS...     NaN          NaN
# 32312  DSTC Electronic Stability Control (ESC)\r\nABS...     NaN          NaN
# 32313  DSTC Electronic Stability Control (ESC)\r\nABS...     NaN          NaN
# 32314  DSTC Electronic Stability Control (ESC)\r\nABS...     NaN          NaN
# 32315  DSTC Electronic Stability Control (ESC)\r\nABS...     NaN          NaN
#
#        Volume  Width  Height  Length    Size_avg Airbag_Front_Driver  \
# 0         NaN   74.8    65.7     NaN   46.833333                 Yes
# 1         NaN   74.8    65.7     NaN   46.833333                 Yes
# 2         NaN   74.8    65.7     NaN   46.833333                 Yes
# 3         NaN   74.8    65.7     NaN   46.833333                 Yes
# 4         NaN   74.8    65.7     NaN   46.833333                 Yes
# 5         NaN   74.8    65.7     NaN   46.833333                 Yes
# 6         NaN   74.8    65.7     NaN   46.833333                 Yes
# 7         NaN   73.7    65.0     NaN   46.233333                 Yes
# 8         NaN   73.7    65.0     NaN   46.233333                 Yes
# 9         NaN   73.7    65.0     NaN   46.233333                 Yes
# 10        NaN   73.7    65.0     NaN   46.233333                 Yes
# 11        NaN   73.7    65.0     NaN   46.233333                 Yes
# 12        NaN   73.7    65.0     NaN   46.233333                 Yes
# 13        NaN   73.7    65.0     NaN   46.233333                 Yes
# 14        NaN   73.7    65.0     NaN   46.233333                 Yes
# 15        NaN   73.7    65.0     NaN   46.233333                 Yes
# 16        NaN   73.7    65.0     NaN   46.233333                 Yes
# 17        NaN   73.7    65.0     NaN   46.233333                 Yes
# 18        NaN   73.7    65.0     NaN   46.233333                 Yes
# 19        NaN   73.7    65.0     NaN   46.233333                 Yes
# 20        NaN   73.7    65.0     NaN   46.233333                 Yes
# 21        NaN   73.7    65.0     NaN   46.233333                 Yes
# 13                 Yes                No        Yes         No        Yes
# 14                 Yes                No        Yes         No        Yes
# 15                 Yes                No        Yes         No        Yes
# 16                 Yes                No        Yes         No        Yes
# 17                 Yes                No        Yes         No        Yes
# 18                 Yes                No        Yes         No        Yes
# 19                 Yes                No        Yes         No        Yes
# 20                 Yes                No        Yes         No        Yes
# 21                 Yes                No        Yes         No        Yes
# 22                 Yes                No        Yes         No        Yes
# 23                 Yes                No        Yes         No        Yes
# 24                 Yes                No        Yes         No        Yes
# 25                 Yes                No        Yes         No        Yes
# 26                 Yes                No        Yes         No        Yes
# 27                 Yes                No        Yes         No        Yes
# 28                 Yes                No        Yes         No        Yes
# 29                 Yes                No        Yes         No        Yes
# ...                ...               ...        ...        ...        ...
# 32286              Yes                No        Yes         No        Yes
# 32287              Yes                No        Yes         No        Yes
# 32288              Yes                No        Yes         No        Yes
# 32289              Yes                No        Yes         No        Yes
# 32290              Yes                No        Yes         No        Yes
# 32291              Yes                No        Yes         No        Yes
# 32292              Yes                No        Yes         No        Yes
# 32293              Yes                No        Yes         No        Yes
# 32294              Yes                No        Yes         No        Yes
# 32295              Yes                No        Yes         No        Yes
# 32296              Yes                No        Yes         No        Yes
# 32297              Yes                No        Yes         No        Yes
# 32298              Yes                No        Yes         No        Yes
# 32299              Yes                No        Yes         No        Yes
# 32300              Yes                No        Yes         No        Yes
# 32301              Yes                No        Yes         No        Yes
# 32302              Yes                No        Yes         No        Yes
# 32303              Yes                No        Yes         No        Yes
# 32304              Yes                No        Yes         No        Yes
# 32305              Yes                No        Yes         No        Yes
# 32306              Yes                No        Yes         No        Yes
# 32307              Yes                No        Yes         No        Yes
# 32308              Yes                No        Yes         No        Yes
# 32309              Yes                No        Yes         No         No
# 32310              Yes                No        Yes         No        Yes
# 32311              Yes                No        Yes         No        Yes
# 32312              Yes                No        Yes         No        Yes
# 32313              Yes                No        Yes         No        Yes
# 32314              Yes                No        Yes         No        Yes
# 32315              Yes                No        Yes         No        Yes
#
#       Airbag_SHR Child_Door_Locks Day_Lights Trac_Control Night_Vision  \
# 0            Yes              Yes        Yes          Yes           No
# 1            Yes              Yes        Yes          Yes           No
# 2            Yes              Yes        Yes          Yes           No
# 3            Yes              Yes        Yes          Yes           No
# 4            Yes              Yes        Yes          Yes           No
# 5            Yes              Yes        Yes          Yes           No
# 6            Yes              Yes        Yes          Yes           No
# 7            Yes              Yes        Yes          Yes           No
# 8            Yes              Yes        Yes          Yes           No
# 9            Yes              Yes        Yes          Yes           No
# 10           Yes              Yes        Yes          Yes           No
# 11           Yes              Yes        Yes          Yes           No
# 12           Yes              Yes        Yes          Yes           No
# 13           Yes              Yes        Yes          Yes           No
# 14           Yes              Yes        Yes          Yes           No
# 15           Yes              Yes        Yes          Yes           No
# 16           Yes              Yes        Yes          Yes           No
# 17           Yes              Yes        Yes          Yes           No
# 18           Yes              Yes        Yes          Yes           No
# 19           Yes              Yes        Yes          Yes           No
# 20           Yes              Yes        Yes          Yes           No
# 21           Yes              Yes        Yes          Yes           No
# 32286   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32287   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32288   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32289   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32290   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32291   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32292   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32293   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32294   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32295   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32296   MacPherson Strut   w/Coil Springs  Independent Multilink
# 32297    Double Wishbone  Double Wishbone             Multi-Link
# 32298    Double Wishbone  Double Wishbone             Multi-Link
# 32299    Double Wishbone  Double Wishbone             Multi-Link
# 32300    Double Wishbone  Double Wishbone             Multi-Link
# 32301    Double Wishbone  Double Wishbone             Multi-Link
# 32302    Double Wishbone  Double Wishbone             Multi-Link
# 32303    Double Wishbone  Double Wishbone             Multi-Link
# 32304    Double Wishbone  Double Wishbone             Multi-Link
# 32305    Double Wishbone  Double Wishbone             Multi-Link
# 32306    Double Wishbone  Double Wishbone             Multi-Link
# 32307    Double Wishbone  Double Wishbone             Multi-Link
# 32308    Double Wishbone  Double Wishbone             Multi-Link
# 32309  MacPherson Struts   w/Coil Springs      Indep. Multi-Leaf
# 32310              Strut            Strut             Multi-Link
# 32311              Strut            Strut             Multi-Link
# 32312              Strut            Strut             Multi-Link
# 32313              Strut            Strut             Multi-Link
# 32314              Strut            Strut             Multi-Link
# 32315              Strut            Strut             Multi-Link
#
#            Susp_Rear2  Trans_Speed  Battery_Amps    HP1    HP2  \
# 0          Multi-Link         10.0           NaN  280.0  272.0
# 1          Multi-Link         10.0           NaN  280.0  272.0
# 2          Multi-Link         10.0           NaN  280.0  272.0
# 3          Multi-Link         10.0           NaN  280.0  272.0
# 4          Multi-Link         10.0           NaN  280.0  272.0
# 5          Multi-Link         10.0           NaN  280.0  272.0
# 6          Multi-Link         10.0           NaN  280.0  272.0
# 7          Multi-Link          6.0         550.0  252.0  279.0
# 8          Multi-Link          6.0         550.0  252.0  279.0
# 9          Multi-Link          6.0         550.0  252.0  279.0
# 10         Multi-Link          6.0         550.0  252.0  279.0
# 11         Multi-Link          6.0         550.0  252.0  279.0
# 12         Multi-Link          6.0         550.0  252.0  279.0
# 13         Multi-Link          6.0         550.0  252.0  279.0
# 14         Multi-Link          6.0         550.0  252.0  279.0
# 15         Multi-Link          6.0         550.0  252.0  279.0
# 16         Multi-Link          6.0         550.0  252.0  279.0
# 17         Multi-Link          6.0         550.0  252.0  279.0
# 18         Multi-Link          6.0         550.0  252.0  279.0
# 19         Multi-Link          6.0         550.0  252.0  279.0
# 20         Multi-Link          6.0         550.0  252.0  279.0
# 21         Multi-Link          6.0         550.0  252.0  279.0
# 22         Multi-Link          6.0         550.0  252.0  279.0
# 23         Multi-Link          6.0         550.0  252.0  279.0
# 24         Multi-Link          6.0         550.0  252.0  279.0
# 25         Multi-Link          6.0         550.0  252.0  279.0
# 26         Multi-Link          6.0         550.0  252.0  279.0
# 27         Multi-Link          6.0         550.0  251.0  273.0
# 28         Multi-Link          6.0         550.0  251.0  273.0
# 29         Multi-Link          6.0         550.0  251.0  273.0
# ...               ...          ...           ...    ...    ...
# 32286  w/Coil Springs          5.0           NaN  236.0  208.0
# 32287  w/Coil Springs          4.0           NaN  280.0  268.0
# 32288  w/Coil Springs          4.0           NaN  280.0  268.0
# 32289  w/Coil Springs          5.0           NaN  236.0  208.0
# 32290  w/Coil Springs          5.0           NaN  236.0  208.0
# 32291  w/Coil Springs          5.0           NaN  236.0  208.0
# 32292  w/Coil Springs          5.0           NaN  236.0  208.0
# 32293  w/Coil Springs          5.0           NaN  236.0  208.0
# 32294  w/Coil Springs          5.0           NaN  236.0  208.0
# 32295  w/Coil Springs          4.0           NaN  280.0  268.0
# 32296  w/Coil Springs          5.0           NaN  236.0  208.0
# 32297      Multi-Link          8.0         800.0  258.0  250.0
# 32298      Multi-Link          8.0         800.0  472.0  400.0
# 32299      Multi-Link          8.0         800.0  472.0  400.0
# 32300      Multi-Link          8.0         800.0  295.0  316.0
# 32301      Multi-Link          8.0         800.0  295.0  316.0
# 32302      Multi-Link          8.0         800.0  258.0  250.0
# 32303      Multi-Link          8.0         800.0  258.0  250.0
# 32304      Multi-Link          8.0         800.0  472.0  402.0
# 32305      Multi-Link          8.0         800.0  472.0  402.0
# 32306      Multi-Link          8.0         800.0  295.0  316.0
# 32307      Multi-Link          8.0         800.0  295.0  316.0
# 32308      Multi-Link          8.0         800.0  258.0  250.0
# 32309  w/Leaf Springs          4.0         600.0  199.0  181.0
# 32310      Multi-Link          8.0         760.0  258.0  240.0
# 32311      Multi-Link          8.0         760.0  258.0  240.0
# 32312      Multi-Link          6.0         600.0  266.0  250.0
# 32313      Multi-Link          6.0         600.0  266.0  250.0
# 32314      Multi-Link          6.0         600.0  266.0  250.0
# 32315      Multi-Link          6.0         600.0  266.0  250.0
#
#                                    Engine_Type  Displacement  Corrosion_Miles  \
# 0                   Turbo Premium Unleaded I-4           2.0         300000.0
# 1                   Turbo Premium Unleaded I-4           2.0         300000.0
# 2                   Turbo Premium Unleaded I-4           2.0         300000.0
# 3                   Turbo Premium Unleaded I-4           2.0         300000.0
# 4                   Turbo Premium Unleaded I-4           2.0         300000.0
# 5                   Turbo Premium Unleaded I-4           2.0         300000.0
# 6                   Turbo Premium Unleaded I-4           2.0         300000.0
# 7                         Premium Unleaded V-6           3.5         300000.0
# 8                         Premium Unleaded V-6           3.5         300000.0
# 9                         Premium Unleaded V-6           3.5         300000.0
# 10                        Premium Unleaded V-6           3.5         300000.0
# 11                        Premium Unleaded V-6           3.5         300000.0
# 12                        Premium Unleaded V-6           3.5         300000.0
# 13                        Premium Unleaded V-6           3.5         300000.0
# 14                        Premium Unleaded V-6           3.5         300000.0
# 15                        Premium Unleaded V-6           3.5         300000.0
# 16                        Premium Unleaded V-6           3.5         300000.0
# 17                        Premium Unleaded V-6           3.5         300000.0
# 18                        Premium Unleaded V-6           3.5         300000.0
# 19                        Premium Unleaded V-6           3.5         300000.0
# 20                        Premium Unleaded V-6           3.5         300000.0
# 21                        Premium Unleaded V-6           3.5         300000.0
# 22                        Premium Unleaded V-6           3.5         300000.0
# 23                        Premium Unleaded V-6           3.5         300000.0
# 24                        Premium Unleaded V-6           3.5         300000.0
# 25                        Premium Unleaded V-6           3.5         300000.0
# 26                        Premium Unleaded V-6           3.5         300000.0
# 27                        Premium Unleaded V-6           3.5         300000.0
# 28                        Premium Unleaded V-6           3.5         300000.0
# 29                        Premium Unleaded V-6           3.5         300000.0
# ...                                        ...           ...              ...
# 32286                             Turbo Gas I5           2.5         300000.0
# 32287                        Twin Turbo Gas I6           2.9         300000.0
# 32288                        Twin Turbo Gas I6           2.9         300000.0
# 32289                             Turbo Gas I5           2.5         300000.0
# 32290                             Turbo Gas I5           2.5         300000.0
# 32291                             Turbo Gas I5           2.5         300000.0
# 32292                             Turbo Gas I5           2.5         300000.0
# 32293                             Turbo Gas I5           2.5         300000.0
# 32294                             Turbo Gas I5           2.5         300000.0
# 32295                        Twin Turbo Gas I6           2.9         300000.0
# 32296                             Turbo Gas I5           2.5         300000.0
# 32297   Intercooled Turbo Premium Unleaded I-4           2.0         300000.0
# 32298      Turbo/Supercharger Gas/Electric I-4           2.0         300000.0
# 32299      Turbo/Supercharger Gas/Electric I-4           2.0         300000.0
# 32300  Turbo/Supercharger Premium Unleaded I-4           2.0         300000.0
# 32301  Turbo/Supercharger Premium Unleaded I-4           2.0         300000.0
# 32302   Intercooled Turbo Premium Unleaded I-4           2.0         300000.0
# 32303   Intercooled Turbo Regular Unleaded I-4           2.0         300000.0
# 32304      Turbo/Supercharger Gas/Electric I-4           2.0         300000.0
# 32305      Turbo/Supercharger Gas/Electric I-4           2.0         300000.0
# 32306  Turbo/Supercharger Premium Unleaded I-4           2.0         300000.0
# 32307  Turbo/Supercharger Premium Unleaded I-4           2.0         300000.0
# 32308   Intercooled Turbo Regular Unleaded I-4           2.0         300000.0
# 32309                                   Gas I6           2.9         300000.0
# 32310   Intercooled Turbo Regular Unleaded I-4           2.0         300000.0
# 32311   Intercooled Turbo Regular Unleaded I-4           2.0         300000.0
# 32312   Intercooled Turbo Regular Unleaded I-5           2.5         300000.0
# 32313   Intercooled Turbo Regular Unleaded I-5           2.5         300000.0
# 32314   Intercooled Turbo Regular Unleaded I-5           2.5         300000.0
# 32315   Intercooled Turbo Regular Unleaded I-5           2.5         300000.0
#
#        Corrosion_Years
# 0                  5.0
# 1                  5.0
# 2                  5.0
# 3                  5.0
# 4                  5.0
# 5                  5.0
# 6                  5.0
# 7                  5.0
# 8                  5.0
# 9                  5.0
# 10                 5.0
# 11                 5.0
# 12                 5.0
# 13                 5.0
# 14                 5.0
# 15                 5.0
# 16                 5.0
# 17                 5.0
# 18                 5.0
# 19                 5.0
# 20                 5.0
# 21                 5.0
# 22                 5.0
# 23                 5.0
# 24                 5.0
# 25                 5.0
# 26                 5.0
# 27                 5.0
# 28                 5.0
# 29                 5.0
# ...                ...
# 32286              8.0
# 32287              8.0
# 32288              8.0
# 32289              8.0
# 32290              8.0
# 32291              8.0
# 32292              8.0
# 32293              8.0
# 32294              8.0
# 32295              8.0
# 32296              8.0
# 32297             12.0
# 32298             12.0
# 32299             12.0
# 32300             12.0
# 32301             12.0
# 32302             12.0
# 32303             12.0
# 32304             12.0
# 32305             12.0
# 32306             12.0
# 32307             12.0
# 32308             12.0
# 32309              8.0
# 32310             12.0
# 32311             12.0
# 32312             12.0
# 32313             12.0
# 32314             12.0
# 32315             12.0
#
# [32262 rows x 62 columns]

# %%
df[all].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32262 entries, 0 to 32315
# Data columns (total 62 columns):
# Year                   32262 non-null category
# Model                  32262 non-null object
# Specs                  32262 non-null object
# MSRP                   32262 non-null int64
# EPA_Class              30286 non-null object
# Body_Stype             30546 non-null object
# Drivetrain             30546 non-null object
# Psg_Cp                 32262 non-null int64
# Psg_Doors              32262 non-null int64
# Front_Wheel_Mat        30293 non-null object
# Rear_Wheel_Mat         30293 non-null object
# Basic_Miles            29879 non-null float64
# Basic_Year             30145 non-null float64
# Drivetrain_Miles       29076 non-null float64
# Drivetrain_Years       29374 non-null float64
# Road_Assist_Miles      19088 non-null float64
# Road_Assist_Years      24632 non-null float64
# Max_Alt_Cp             22714 non-null float64
# Maint_Miles            5519 non-null float64
# Maint_Year             5569 non-null float64
# Max_Alt_Watts          1920 non-null float64
# Other_Features         30562 non-null object
# Weight                 8205 non-null float64
# Trailer_cpt            5672 non-null float64
# Volume                 6479 non-null float64
# Width                  30160 non-null float64
# Height                 30089 non-null float64
# Length                 17454 non-null float64
# Size_avg               32262 non-null float64
# Airbag_Front_Driver    32262 non-null object
# Airbag_Front_Psg       32262 non-null object
# Airbag_Psg_Switch      32262 non-null object
# Airbag_SBF             32262 non-null object
# Airbag_SBR             32262 non-null object
# Airbag_SHF             32262 non-null object
# Airbag_SHR             32262 non-null object
# Child_Door_Locks       32262 non-null object
# Day_Lights             32262 non-null object
# Trac_Control           32262 non-null object
# Night_Vision           32262 non-null object
# Rollover_Prt           32262 non-null object
# Fog_Lamps              32262 non-null object
# Parking_Aid            32262 non-null object
# Tire_P_Monitor         32262 non-null object
# Backup_Camera          32262 non-null object
# Stability_Ctl          32262 non-null object
# Fuel_Tank_Cpt          30095 non-null float64
# MPG_avg                17369 non-null float64
# MPG_City               26990 non-null float64
# MPG_Hwy                26986 non-null float64
# Susp_Front             30260 non-null object
# Susp_Front2            15149 non-null object
# Susp_Rear              30249 non-null object
# Susp_Rear2             15058 non-null object
# Trans_Speed            30230 non-null float64
# Battery_Amps           15927 non-null float64
# HP1                    28602 non-null float64
# HP2                    29452 non-null float64
# Engine_Type            30288 non-null object
# Displacement           30124 non-null float64
# Corrosion_Miles        29258 non-null float64
# Corrosion_Years        29296 non-null float64
# dtypes: category(1), float64(28), int64(3), object(30)
# memory usage: 15.3+ MB

# %%
print(time.time()-start)
# Out:
# 128.74653911590576
